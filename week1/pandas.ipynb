# %%
import pandas as pd
#load my dataset into a dataframe
df=pd.read_csv('supermarket_sales.csv')
# df=pd.read_sql_query('SELECT * FROM supermarket_sales', 'sqlite:///supermarket_sales.db')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal     NaN
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#load the top 5 rows of the dataset
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal     NaN
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#load the bottom 5 rows of the dataset
df.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
#check datatypes and information aboit the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   999 non-null    object
#  5   Product line             999 non-null    object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   999 non-null    float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#descripe the numerical columns
df.describe()
# Out:
#         Unit price     Quantity      Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  999.000000  1000.000000  1000.00000
# mean     55.672130     5.510000   15.359038   322.966749   307.58738
# std      26.494628     2.923431   11.697017   245.885335   234.17651
# min      10.080000     1.000000    0.508500    10.678500    10.17000
# 25%      32.875000     3.000000    5.894750   124.422375   118.49750
# 50%      55.230000     5.000000   12.080000   253.848000   241.76000
# 75%      77.935000     8.000000   22.429000   471.350250   448.90500
# max      99.960000    10.000000   49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# ...

# %%
#shape of the dataframe
df.shape
# Out:
# (1000, 17)

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal     NaN
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#preprocessing
#check for missing values
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     1
# Product line               1
# Unit price                 0
# Quantity                   0
# Tax 5%                     1
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#remove entire records for missing values 
# df['City'].dropna(inplace=True) 
df.dropna(inplace=True)

# %%
#fill missing values with a specific value
df.fillna(0, inplace=True)

# %%
#rename a column
df.rename(columns={'Customer type':'Customer_type'}, inplace=True)

# %%
#check for duplicates
df.duplicated().sum()
df.drop_duplicates()
# Out:
#       Invoice ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer_type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#extract one column from the dataframe
city_df=df['City']
city_df
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 5      Naypyitaw
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 997, dtype: object

# %%
#extract multiple columns from the dataframe
df2=df[['Invoice ID', 'Branch', 'City', 'Customer_type', 'Gender']]

df2.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male

# %%
#extracting the top 2 rows
rows=df.iloc[:2]
rows
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6

# %%
price=rows.iloc[0,6]
price
# Out:
# 74.69

# %%
#adding a new column to the dataframe
df['Total Price']=df['Unit price']*df['Quantity']

df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 5  Electronic accessories       85.39         7  29.8865  627.6165  3/25/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#add a colunsn of 0's
df['new_col']=0

df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 5  Electronic accessories       85.39         7  29.8865  627.6165  3/25/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#delete column
df.drop('new_col', axis=1,inplace=True)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 5  Electronic accessories       85.39         7  29.8865  627.6165  3/25/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#drop more than one col
df['new_col']=0

df.drop(['new_col','Total Price'], axis=1,inplace=True)

df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 5  Electronic accessories       85.39         7  29.8865  627.6165  3/25/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.iloc[0,1]="B"
df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      B     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 5  Electronic accessories       85.39         7  29.8865  627.6165  3/25/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#filter by males only
males_df=df[(df['Gender']=='Male') & (df['City']=='Yangon')]

males_df.head()
# Out:
#      Invoice ID Branch    City Customer_type Gender        Product line  \
# 2   631-41-3108      A  Yangon        Normal   Male  Home and lifestyle
# 3   123-19-1176      A  Yangon        Member   Male   Health and beauty
# 13  252-56-2699      A  Yangon        Normal   Male  Food and beverages
# 17  765-26-6951      A  Yangon        Normal   Male   Sports and travel
# 18  329-62-1586      A  Yangon        Normal   Male  Food and beverages
#
#     Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 2        46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3        58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 13       43.19        10  21.5950  453.4950   2/7/2019  16:48      Ewallet
# 17       72.61         6  21.7830  457.4430   1/1/2019  10:39  Credit card
# 18       54.67         3   8.2005  172.2105  1/21/2019  18:00  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# ...

# %%
males_df.shape
# Out:
# (178, 17)

# %%
#sort the dataframe according to the highest total first
males_df.sort_values('Total', ascending=False,inplace=True)
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_42895/1183132740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   males_df.sort_values('Total', ascending=False,inplace=True)

# %%
males_df.tail(5)
# Out:
#       Invoice ID Branch    City Customer_type Gender         Product line  \
# 861  840-76-5966      A  Yangon        Member   Male    Sports and travel
# 453  568-88-3448      A  Yangon        Normal   Male    Health and beauty
# 844  896-34-0956      A  Yangon        Normal   Male  Fashion accessories
# 732  756-49-0168      A  Yangon        Member   Male  Fashion accessories
# 215  802-43-8934      A  Yangon        Normal   Male   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%   Total       Date   Time      Payment  \
# 861       12.76         2   1.276  26.796   1/8/2019  18:06      Ewallet
# 453       25.00         1   1.250  26.250   3/3/2019  15:09      Ewallet
# 844       21.32         1   1.066  22.386  1/26/2019  12:43         Cash
# 732       19.70         1   0.985  20.685   2/8/2019  11:39      Ewallet
# 215       18.28         1   0.914  19.194  3/22/2019  15:05  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# ...

# %%
#query
males_df.query('Customer_type=="Member" & Branch=="A"')
# Out:
#       Invoice ID Branch    City Customer_type Gender            Product line  \
# 105  704-48-3927      A  Yangon        Member   Male  Electronic accessories
# 889  880-46-5796      A  Yangon        Member   Male       Sports and travel
# 652  742-04-5161      A  Yangon        Member   Male      Home and lifestyle
# 531  435-13-4908      A  Yangon        Member   Male     Fashion accessories
# 614  443-59-0061      A  Yangon        Member   Male      Food and beverages
# ..           ...    ...     ...           ...    ...                     ...
# 961  324-92-3863      A  Yangon        Member   Male  Electronic accessories
# 717  482-17-1179      A  Yangon        Member   Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member   Male      Food and beverages
# 861  840-76-5966      A  Yangon        Member   Male       Sports and travel
# 732  756-49-0168      A  Yangon        Member   Male     Fashion accessories
#
# ...

# %%
#get distinct branches that are in the dataframe
df['Branch'].unique()
df['Branch'].groupby(df['Branch']).count()
# Out:
# Branch
# A    337
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      B     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 5  Electronic accessories       85.39         7  29.8865  627.6165  3/25/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
#grouping
df.groupby('City').mean()
# Out:
#            Unit price  Quantity     Tax 5%       Total        cogs  \
# City
# Mandalay    55.661752  5.489426  15.253190  320.316997  305.063807
# Naypyitaw   56.609024  5.582317  16.052367  337.099715  321.047348
# Yangon      54.638462  5.449704  14.767047  310.107994  295.340947
#
#            gross margin percentage  gross income    Rating
# City
# Mandalay                  4.761905     15.253190  6.820846
# Naypyitaw                 4.761905     16.052367  7.072866
# Yangon                    4.761905     14.767047  7.036095

# %%
males_df
# Out:
#       Invoice ID Branch    City Customer_type Gender            Product line  \
# 167  687-47-8271      A  Yangon        Normal   Male     Fashion accessories
# 105  704-48-3927      A  Yangon        Member   Male  Electronic accessories
# 529  827-77-7633      A  Yangon        Normal   Male       Sports and travel
# 739  805-86-0265      A  Yangon        Normal   Male      Home and lifestyle
# 68   232-11-3025      A  Yangon        Normal   Male       Sports and travel
# ..           ...    ...     ...           ...    ...                     ...
# 861  840-76-5966      A  Yangon        Member   Male       Sports and travel
# 453  568-88-3448      A  Yangon        Normal   Male       Health and beauty
# 844  896-34-0956      A  Yangon        Normal   Male     Fashion accessories
# 732  756-49-0168      A  Yangon        Member   Male     Fashion accessories
# 215  802-43-8934      A  Yangon        Normal   Male      Home and lifestyle
#
# ...

# %%
males_df.to_csv('males_result.csv', index=False)

# %%
#boxplot
import matplotlib.pyplot as plt

df.boxplot(column='Total',showfliers=True)
# Out:
# <Axes: >

# %%
filtered_df=df.query('Total<950')
filtered_df.head()
# Out:
#     Invoice ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      B     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 5  Electronic accessories       85.39         7  29.8865  627.6165  3/25/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
filtered_df.boxplot(column='Total',showfliers=True)
plt.show()

# %%
import matplotlib.pyplot as plt

# create a list of x-coordinates
x = [1, 2, 3, 4, 5]

# create a list of y-coordinates
y = [1, 4, 9, 16, 25]

# create a line plot
plt.plot(x, y)

# add labels and a title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Plot')

# display the plot
plt.show()

# %%
males_df.head()
# Out:
#       Invoice ID Branch    City Customer_type Gender            Product line  \
# 167  687-47-8271      A  Yangon        Normal   Male     Fashion accessories
# 105  704-48-3927      A  Yangon        Member   Male  Electronic accessories
# 529  827-77-7633      A  Yangon        Normal   Male       Sports and travel
# 739  805-86-0265      A  Yangon        Normal   Male      Home and lifestyle
# 68   232-11-3025      A  Yangon        Normal   Male       Sports and travel
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 167       98.98        10  49.4900  1039.2900   2/8/2019  16:20  Credit card
# 105       88.67        10  44.3350   931.0350  1/12/2019  14:50      Ewallet
# 529       98.09         9  44.1405   926.9505  2/17/2019  19:41         Cash
# 739       93.96         9  42.2820   887.9220  3/20/2019  11:32         Cash
# 68        78.77        10  39.3850   827.0850  1/24/2019  10:04         Cash
#
# ...

# %%
import matplotlib.pyplot as plt

#Plot line plot of rating compared to unit price

x=males_df['Total']
y=males_df['gross income']

plt.title('Total vs Gross Income')
plt.xlabel('Total')
plt.ylabel('Gross Income')
plt.plot(x,y)
plt.show()

# %%
males_df.plot(x='Total', y='gross income', kind='scatter')
plt.show()

# %%
product_df=df.groupby('Product line').mean()['Total']
product_df
#bar plot

product_df.plot(kind='bar')
plt.title('Product line vs Total')
plt.xlabel('Product line')
plt.ylabel('Total')
plt.show()

# %%
males_df.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000 -0.043861  0.591859  0.591859  0.591859
# Quantity                  -0.043861  1.000000  0.703643  0.703643  0.703643
# Tax 5%                     0.591859  0.703643  1.000000  1.000000  1.000000
# Total                      0.591859  0.703643  1.000000  1.000000  1.000000
# cogs                       0.591859  0.703643  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.591859  0.703643  1.000000  1.000000  1.000000
# Rating                    -0.019510  0.019572  0.023959  0.023959  0.023959
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.591859 -0.019510
# Quantity                                     NaN      0.703643  0.019572
# ...

# %%
import seaborn as sns
#plot aheatmap to understand the correlations between the different params
males_df.drop('gross margin percentage', axis=1, inplace=True)

sns.heatmap(males_df.corr(), annot=True)
plt.show()
# Out:
# /var/folders/f0/8zss9bcx2pq3p607h6tvt1sr0000gn/T/ipykernel_42895/856339908.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   males_df.drop('gross margin percentage', axis=1, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create some data
x = [1, 2, 3, 4, 5]
y = [10, 8, 6, 4, 2]

# Create the plot
sns.lineplot(x=x, y=y)

# Show the plot
plt.show()
